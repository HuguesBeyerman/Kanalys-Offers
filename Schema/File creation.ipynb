# %%
customers = [{'customer_id': 1,
  'first_name': 'Eric',
  'last_name': 'Wise',
  'email': 'wendybrown@yahoo.com',
  'phone_number': '001-354-930-5535',
  'date_of_birth': '2003-06-15',
  'address': {'street': '06983 Jason Ports Suite 011',
   'city': 'Lake Mathewshire',
   'postal_code': '36902',
   'country': 'Armenia'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2020-07-19',
  'VAT': 'xp926304432',
  'Bank account': 'GB06QIWE76710602273873'},
 {'customer_id': 2,
  'first_name': 'Jamie',
  'last_name': 'Johnson',
  'email': 'shannon85@hotmail.com',
  'phone_number': '+1-553-875-6573x50360',
  'date_of_birth': '1933-12-30',
  'address': {'street': '87247 Justin Valleys',
   'city': 'Pamelafurt',
   'postal_code': '81058',
   'country': 'Azerbaijan'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2022-08-19',
  'VAT': 'th776834087',
  'Bank account': 'GB42XWBU74247928842241'},
 {'customer_id': 3,
  'first_name': 'Stephanie',
  'last_name': 'Pearson',
  'email': 'xgraham@norton-jones.com',
  'phone_number': '130.001.0448x895',
  'date_of_birth': '1964-11-03',
  'address': {'street': '9335 Lindsey Stravenue Suite 967',
   'city': 'Cervantesmouth',
   'postal_code': '86658',
   'country': 'Oman'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2023-12-24',
  'VAT': 'Qe048424706',
  'Bank account': 'GB33DPDF11644339172876'},
 {'customer_id': 4,
  'first_name': 'Kara',
  'last_name': 'Rodriguez',
  'email': 'cynthia15@hotmail.com',
  'phone_number': '001-532-879-0430',
  'date_of_birth': '2006-08-07',
  'address': {'street': '692 Albert Trafficway',
   'city': 'Lake Pamela',
   'postal_code': '16407',
   'country': 'Cameroon'},
  'company_name': 'Hill, Wong and Armstrong',
  'customer_type': 'Business',
  'account_creation_date': '2020-10-28',
  'VAT': 'Ce979919353',
  'Bank account': 'GB84CKAY98215132894028'},
 {'customer_id': 5,
  'first_name': 'Mark',
  'last_name': 'Schultz',
  'email': 'mendozathomas@dominguez-lopez.com',
  'phone_number': '+1-899-396-3585x1136',
  'date_of_birth': '1999-11-17',
  'address': {'street': '44941 William Roads',
   'city': 'New Melanietown',
   'postal_code': '17660',
   'country': 'Ghana'},
  'company_name': 'Reeves, Harrell and Booker',
  'customer_type': 'Business',
  'account_creation_date': '2020-01-08',
  'VAT': 'eC371104624',
  'Bank account': 'GB85WSXQ25257441462377'},
 {'customer_id': 6,
  'first_name': 'Zachary',
  'last_name': 'Jones',
  'email': 'scott55@hotmail.com',
  'phone_number': '001-410-531-0187',
  'date_of_birth': '1936-01-17',
  'address': {'street': '770 Joe Causeway',
   'city': 'Williammouth',
   'postal_code': '71494',
   'country': 'Latvia'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2023-10-09',
  'VAT': 'ox258106696',
  'Bank account': 'GB69KGGZ75042246065436'},
 {'customer_id': 7,
  'first_name': 'Marcus',
  'last_name': 'Miller',
  'email': 'robertovalentine@hotmail.com',
  'phone_number': '009.267.2264',
  'date_of_birth': '2002-02-20',
  'address': {'street': '285 Dawn Isle',
   'city': 'Lauratown',
   'postal_code': '47433',
   'country': 'Latvia'},
  'company_name': 'Reed-Hurley',
  'customer_type': 'Business',
  'account_creation_date': '2024-07-10',
  'VAT': 'oX538195730',
  'Bank account': 'GB92ZCBY72616148912778'},
 {'customer_id': 8,
  'first_name': 'Robin',
  'last_name': 'Lin',
  'email': 'nicole50@morse.info',
  'phone_number': '(369)069-5922x64330',
  'date_of_birth': '1995-12-25',
  'address': {'street': '574 Sandoval Course Apt. 650',
   'city': 'Paulaview',
   'postal_code': '92204',
   'country': 'Ukraine'},
  'company_name': 'Dillon PLC',
  'customer_type': 'Business',
  'account_creation_date': '2024-06-11',
  'VAT': 'du344050579',
  'Bank account': 'GB72FJXW60948951904792'},
 {'customer_id': 9,
  'first_name': 'Keith',
  'last_name': 'Fisher',
  'email': 'darrenmayer@gmail.com',
  'phone_number': '(889)249-2449x6865',
  'date_of_birth': '1999-03-20',
  'address': {'street': '8191 Karen Unions',
   'city': 'Westton',
   'postal_code': '07921',
   'country': 'Djibouti'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2022-04-08',
  'VAT': 'ut894291301',
  'Bank account': 'GB08HMBW63921935362761'},
 {'customer_id': 10,
  'first_name': 'Pamela',
  'last_name': 'Lloyd',
  'email': 'woodjulie@rodriguez.com',
  'phone_number': '(096)412-4685x077',
  'date_of_birth': '1969-12-13',
  'address': {'street': '561 Diane Parkway',
   'city': 'Patrickport',
   'postal_code': '72467',
   'country': 'Marshall Islands'},
  'company_name': 'Lambert, Jimenez and Murphy',
  'customer_type': 'Business',
  'account_creation_date': '2024-07-26',
  'VAT': 'BC611465556',
  'Bank account': 'GB80DDDZ13457093515029'},
 {'customer_id': 11,
  'first_name': 'Debra',
  'last_name': 'Miller',
  'email': 'jocelynrogers@mccoy.info',
  'phone_number': '604-312-0531',
  'date_of_birth': '1937-10-25',
  'address': {'street': '478 Mcdowell Ports',
   'city': 'Juanstad',
   'postal_code': '41567',
   'country': 'Uruguay'},
  'company_name': 'Jones-Wood',
  'customer_type': 'Business',
  'account_creation_date': '2020-01-07',
  'VAT': 'qW985881625',
  'Bank account': 'GB64KGFL47001953831079'},
 {'customer_id': 12,
  'first_name': 'Leslie',
  'last_name': 'Simpson',
  'email': 'megan05@bates-charles.com',
  'phone_number': '(547)416-8668',
  'date_of_birth': '1947-03-02',
  'address': {'street': '957 Charles Heights Apt. 573',
   'city': 'New Dawn',
   'postal_code': '35933',
   'country': 'Thailand'},
  'company_name': 'Johnson, Robertson and Gordon',
  'customer_type': 'Business',
  'account_creation_date': '2024-06-02',
  'VAT': 'Iv320094712',
  'Bank account': 'GB62ZUCP23014783397887'},
 {'customer_id': 13,
  'first_name': 'Erika',
  'last_name': 'Brown',
  'email': 'wandawalters@gmail.com',
  'phone_number': '938-047-0753',
  'date_of_birth': '1948-09-17',
  'address': {'street': '2215 Richard Harbors Apt. 901',
   'city': 'Yoderfort',
   'postal_code': '28270',
   'country': 'Niue'},
  'company_name': 'Walsh-Reyes',
  'customer_type': 'Business',
  'account_creation_date': '2023-10-02',
  'VAT': 'JB102639592',
  'Bank account': 'GB84VYCF63341826200542'},
 {'customer_id': 14,
  'first_name': 'Priscilla',
  'last_name': 'Mason',
  'email': 'jacquelinebush@johnson.com',
  'phone_number': '(566)602-4070x282',
  'date_of_birth': '2003-09-01',
  'address': {'street': '7594 Deanna Groves Suite 362',
   'city': 'New Matthew',
   'postal_code': '01943',
   'country': 'Eritrea'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2021-06-24',
  'VAT': 'PA536131340',
  'Bank account': 'GB43MXXW14919912318136'},
 {'customer_id': 15,
  'first_name': 'Brandon',
  'last_name': 'Torres',
  'email': 'wfitzpatrick@alvarez.com',
  'phone_number': '505.698.4128x59496',
  'date_of_birth': '1976-12-25',
  'address': {'street': '61666 Bell Islands',
   'city': 'East Anthonyland',
   'postal_code': '86937',
   'country': 'Netherlands Antilles'},
  'company_name': 'Lee-Harris',
  'customer_type': 'Business',
  'account_creation_date': '2020-10-29',
  'VAT': 'HO066740004',
  'Bank account': 'GB55HWLH77408217641768'},
 {'customer_id': 16,
  'first_name': 'Ann',
  'last_name': 'Wilkins',
  'email': 'znguyen@johnson-thompson.com',
  'phone_number': '(191)917-7073x9517',
  'date_of_birth': '1995-08-17',
  'address': {'street': '1751 Ryan Cove',
   'city': 'Port Christopher',
   'postal_code': '52089',
   'country': 'Russian Federation'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2021-07-23',
  'VAT': 'cG767222249',
  'Bank account': 'GB10XIWS01842729705172'},
 {'customer_id': 17,
  'first_name': 'Emily',
  'last_name': 'Miller',
  'email': 'katherinelynch@rose.com',
  'phone_number': '3473458632',
  'date_of_birth': '1966-07-28',
  'address': {'street': '339 Sandoval Rapids',
   'city': 'West Victoriamouth',
   'postal_code': '89095',
   'country': 'Samoa'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2023-06-21',
  'VAT': 'Ey226339251',
  'Bank account': 'GB10ALBN21241233000673'},
 {'customer_id': 18,
  'first_name': 'Edward',
  'last_name': 'Moore',
  'email': 'rcervantes@gmail.com',
  'phone_number': '531-465-4841x4919',
  'date_of_birth': '1961-03-06',
  'address': {'street': '4720 Meredith Summit',
   'city': 'Lake Phyllismouth',
   'postal_code': '31195',
   'country': 'Comoros'},
  'company_name': 'Mcdaniel, Phillips and Bruce',
  'customer_type': 'Business',
  'account_creation_date': '2024-05-18',
  'VAT': 'BL722281673',
  'Bank account': 'GB06WUNG59248770422581'},
 {'customer_id': 19,
  'first_name': 'Crystal',
  'last_name': 'Abbott',
  'email': 'mariatorres@frank.com',
  'phone_number': '778.543.3203x931',
  'date_of_birth': '1962-09-28',
  'address': {'street': '998 White Stravenue',
   'city': 'Emilyside',
   'postal_code': '51954',
   'country': 'Namibia'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2024-06-27',
  'VAT': 'nQ288047804',
  'Bank account': 'GB70RTFF98076542048269'},
 {'customer_id': 20,
  'first_name': 'Stacy',
  'last_name': 'Stewart',
  'email': 'jberg@barnes.com',
  'phone_number': '781.999.5733',
  'date_of_birth': '1934-07-19',
  'address': {'street': '40531 Carly Fields Suite 161',
   'city': 'Port Ryanland',
   'postal_code': '12542',
   'country': 'Palau'},
  'company_name': None,
  'customer_type': 'Individual',
  'account_creation_date': '2020-04-14',
  'VAT': 'FK297325619',
  'Bank account': 'GB22PAKA17645888018624'}]

# %%
cust = {}
for i in customers:
    a = list(i.keys())
    c = list(i['address'].keys())
    x = a+c
    b = list(i.values())
    d = list(i['address'].values())
    y = b+d
    cust[int(b[0])] = dict(zip(x[1:], y[1:]))
    del  cust[int(b[0])]['address']

# %%
sewer_products_services = [
    {
        "product_id": 1,
        "description": "Sewer line repair (per meter)",
        "unit_selling_price": 150.00,
        "unit_cost": 90.00
    },
    {
        "product_id": 2,
        "description": "Sewer maintenance inspection (per hour)",
        "unit_selling_price": 100.00,
        "unit_cost": 60.00
    },
    {
        "product_id": 3,
        "description": "Sewer blockage removal (per blockage)",
        "unit_selling_price": 200.00,
        "unit_cost": 120.00
    },
    {
        "product_id": 4,
        "description": "Sewer camera inspection (per hour)",
        "unit_selling_price": 180.00,
        "unit_cost": 100.00
    },
    {
        "product_id": 5,
        "description": "High-pressure sewer cleaning (per meter)",
        "unit_selling_price": 80.00,
        "unit_cost": 50.00
    },
    {
        "product_id": 6,
        "description": "Sewer relining (per meter)",
        "unit_selling_price": 250.00,
        "unit_cost": 160.00
    },
    {
        "product_id": 7,
        "description": "Emergency sewer repair (callout fee)",
        "unit_selling_price": 300.00,
        "unit_cost": 180.00
    },
    {
        "product_id": 8,
        "description": "Sewer odor inspection and repair (per session)",
        "unit_selling_price": 120.00,
        "unit_cost": 75.00
    },
    {
        "product_id": 9,
        "description": "Sewer maintenance contract (annual)",
        "unit_selling_price": 1000.00,
        "unit_cost": 650.00
    },
    {
        "product_id": 10,
        "description": "Sewer camera rental (per day)",
        "unit_selling_price": 250.00,
        "unit_cost": 120.00
    }
]

# %%
prod = {}
for i in sewer_products_services:
    a = list(i.keys())

    b = list(i.values())

    prod[int(b[0])] = dict(zip(a[1:], b[1:]))

# %%
par  = {
    1: {'description': 'déplacement','Paragraph':"""Lorem ipsum dolor sit amet, consectetur {0} adipiscing elit. Pellentesque in magna vehicula, vehicula est sit amet, {1} condimentum nunc. Sed ut neque quam. Aliquam quis aliquet justo. Praesent pharetra, velit eu dapibus venenatis, lectus {2} velit gravida turpis, nec suscipit purus orci at ipsum. Nulla ac urna sit amet urna mollis malesuada. Morbi tincidunt sem non felis vehicula, non iaculis velit fermentum. Sed vulputate quam ac magna volutpat, nec vehicula arcu cursus. Maecenas at leo mauris. Nam efficitur interdum urna, vel auctor metus cursus sit amet.""", 'elt': {0: 'longueur', 1:'largeur', 2:'hauteur'}},
    2: {'description': 'montage échaffaudage','Paragraph':"""Aenean sit amet convallis magna. Nulla {0} facilisi. Vestibulum et justo a elit vulputate feugiat. Vestibulum sodales metus non enim sagittis, id fermentum leo consectetur. Mauris lacinia turpis nec magna {2} scelerisque, at malesuada libero scelerisque. Fusce posuere libero a nisi ultrices, {1} eget hendrerit augue tincidunt. Phasellus ut dignissim elit. Morbi id elit sem. In id scelerisque velit. Donec suscipit velit vel lorem posuere, sit amet congue ex interdum. Duis lacinia enim eu velit tincidunt, at fermentum lorem vehicula.""", 'elt': {0: 'longueur', 1:'largeur', 2:'hauteur'}},
    14: {'description': 'démontage','Paragraph':"""Vivamus vehicula mi id eros {0} porttitor, sed fermentum enim vehicula. Sed suscipit {1} velit sed eros venenatis, id lobortis tortor suscipit. Integer ut turpis eget ante tempor efficitur sed a dui. Curabitur {2}  at turpis quis justo cursus elementum. Nulla tristique, ligula eget tincidunt fermentum, ante felis tincidunt lorem, vel luctus sem orci ut magna. Cras porttitor feugiat convallis. Integer sit amet augue id dui hendrerit consequat. Donec vel nulla in eros accumsan aliquet. Donec suscipit ipsum sed quam bibendum cursus.""", 'elt': {0: 'longueur', 1:'largeur', 2:'hauteur'}},
    15: {'description': 'nettoyage','Paragraph':"""Etiam sit amet arcu a nulla {0} tristique tincidunt. Aenean aliquet diam in nulla egestas varius. In accumsan {1} volutpat ex, in venenatis lectus pharetra quis. Praesent et turpis eu erat feugiat efficitur {2} sed a mi. Aliquam a neque at libero tempor auctor. Nulla malesuada orci nec velit gravida aliquam. Donec sollicitudin mauris ac efficitur lacinia. Aliquam erat volutpat. Integer congue nisl in augue pharetra, et porttitor erat bibendum. Pellentesque et lorem at velit hendrerit elementum.""", 'elt': {0: 'longueur', 1:'largeur', 2:'hauteur'}}
}

import json

with open('paragraphs.json', 'w') as file:
    json.dump(par, file, indent=4)

# %%
building_addresses = {
    1: {
        "street": "Rue de la Loi",
        "number": 16,
        "postal_code": "1000",
        "city": "Brussels",
        "country": "Belgium",
        "manager": '1'
    },
    2: {
        "street": "Boulevard Anspach",
        "number": 20,
        "postal_code": "1000",
        "city": "Brussels",
        "country": "Belgium",
        "manager": '3'
    },
    3: {
        "street": "Avenue Louise",
        "number": 120,
        "postal_code": "1050",
        "city": "Ixelles",
        "country": "Belgium",
        "manager": '5'
    },
    4: {
        "street": "Chaussée de Waterloo",
        "number": 225,
        "postal_code": "1060",
        "city": "Saint-Gilles",
        "country": "Belgium",
        "manager": '4'
    },
    5: {
        "street": "Rue du Trône",
        "number": 42,
        "postal_code": "1050",
        "city": "Ixelles",
        "country": "Belgium",
        "manager": '4'
    },
    6: {
        "street": "Place du Luxembourg",
        "number": 7,
        "postal_code": "1050",
        "city": "Ixelles",
        "country": "Belgium",
        "manager": '2'
    },
    7: {
        "street": "Boulevard du Souverain",
        "number": 89,
        "postal_code": "1160",
        "city": "Auderghem",
        "country": "Belgium",
        "manager": '7'
    },
    8: {
        "street": "Rue Belliard",
        "number": 202,
        "postal_code": "1040",
        "city": "Etterbeek",
        "country": "Belgium",
        "manager": '2'
    },
    9: {
        "street": "Rue des Palais",
        "number": 33,
        "postal_code": "1030",
        "city": "Schaerbeek",
        "country": "Belgium",
        "manager": '7'
    },
    10: {
        "street": "Avenue Franklin Roosevelt",
        "number": 50,
        "postal_code": "1050",
        "city": "Ixelles",
        "country": "Belgium",
        "manager": '1'
        
    },
    # ... Continuing until 100 addresses ...
    11: {
        "street": "Chaussée de Wavre",
        "number": 310,
        "postal_code": "1040",
        "city": "Etterbeek",
        "country": "Belgium",
        "manager": '4'
    }
}

# %%
import json

# Saving the list as a JSON file
with open("sewer_products_services.json", 'w') as file:
    json.dump(prod, file, indent=4)

with open('customers.json', 'w') as file:
    json.dump(cust, file, indent=4)

with open('paragraphs.json', 'w') as file:
    json.dump(par, file, indent=4)


with open('buildings.json', 'w') as file:
    json.dump(building_addresses, file, indent=4)
