# %%
import json
from datetime import datetime as dt
import click

# %%
class Customer:

    def append_cust_table(self, cust_table):
        cust_table[self.customer_id] = {'title':self.title, 'first_name': self.first_name,
                                        'last_name': self.last_name ,
                                        'company_name ': self.company_name,
                                        'email' : self.email,
                                        'phone_number':self.phone_number ,
                                        'street':elf.street,
                                        'number':self.number,
                                        'postal_code':self.postal_code ,
                                        'city':self.city ,
                                        'country':self.country,
                                        'customer type':self.customer_type,
                                        'account_creation_date':self.account_creation_date,
                                        'VAT':self.VAT ,
                                        'Bank account':self.Bank_account}
        return(cust_table)

    def __init__ (self):
        self.cust_id = 'id'
        self.title = 'title'
        self.first_name = 'first_name'
        self.last_name = 'last_name'
        self.company_name = 'company_name'
        self.email = 'email'
        self.phone_number = 'phone_number'
        self.street = 'street'
        self.number = 'number'
        self.postal_code = 'postal_code'
        self.city = 'city'
        self.country = 'country'
        self.customer_type = 'customer type:'
        self.account_creation_date = dt.today().date().strftime('%d-%m-%y')
        self.VAT = 'VAT:'
        self.Bank_account = 'Bank account:'

        #return(self)

    def define_cust_id(self,cust_table):
        id_list = list(cust_table.keys())
        id_list.sort(reverse = True, key = int)
        self.cust_id = str(int(id_list[0]) + 1)
    
    def modify(self):
        self.title = input('title (default: {}) '.format(self.title) ) or self.title
        self.first_name = input('first_name (default: {}) '.format(self.first_name) ) or self.first_name
        self.last_name = input('last_name (default: {}) '.format(self.last_name)) or self.last_name
        self.company_name = input('company_name (default: {}) '.format(self.company_name)) or self.company_name
        self.email = input('email (default: {}) '.format(self.email)) or self.email
        self.phone_number = input('tel (default: {}) '.format(self.phone_number)) or self.phone_number
        self.street = input('street (default: {}) '.format(self.street)) or self.street
        self.number = input('number (default: {}) '.format(self.number)) or self.number
        self.postal_code = input('postal_code (default: {}) '.format(self.postal_code)) or self.postal_code
        self.city = input('city (default: {}) '.format(self.city)) or self.city
        self.country = input('country (default: {}) '.format(self.country)) or self.country
        self.customer_type = input('customer type: (default: {}) '.format(self.customer_type)) or self.customer_type
        self.account_creation_date = self.account_creation_date
        self.VAT = input('VAT: (default: {}) '.format(self.VAT)) or self.VAT
        self.Bank_account = input('Bank account: (default: {}) '.format(self.Bank_account)) or self.Bank_account

    def import_cust(self, id, cust_table):
        print(cust_table[id])
        self.cust_id = id
        try:
            self.title = cust_table[id]['title']
        except:
            self.title = 'Mr'
        self.first_name = cust_table[id]['first_name']
        self.last_name = cust_table[id]['last_name']
        self.company_name = cust_table[id]['company_name']
        self.email = cust_table[id]['email']
        self.phone_number = cust_table[id]['phone_number']
        self.street = cust_table[id]['street']
        self.number = cust_table[id]['number']
        self.postal_code = cust_table[id]['postal_code']
        self.city = cust_table[id]['city']
        self.country = cust_table[id]['country']
        try:
            self.customer_type = cust_table[id]['customer_type:']
        except:
            self.customer_type = 'prof'
        self.account_creation_date = cust_table[id]['account_creation_date']
        self.VAT = cust_table[id]['VAT']
        self.Bank_account = cust_table[id]['Bank account']

    def export_cust(self):
        a = {self.cust_id : {
            'first_name': self.first_name, 
            'last_name': self.last_name, 
            'email': self.email, 
            'phone_number': self.phone_number , 
            'company_name': self.company_name,
            'customer_type': self.customer_type, 
            'account_creation_date': self.account_creation_date, 
            'VAT': self.VAT, 
            'Bank account': self.Bank_account, 
            'street': self.street, 
            'city': self.city, 
            'postal_code': self.postal_code, 
            'country': self.country, 
            'number': self.number, 
            'titre': self.title}}
        return(a)

        
        
        return(self)

# %%
def start():
    with open("json/customers.json", 'r') as file:
        cust_table = json.load(file)
    cust = Customer
    cust.define_cust_id(cust_table)
    print(cust.cust_id)

start()
# Out:
# 26
